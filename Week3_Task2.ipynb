# %% [markdown]
# import and install required libraries

# %%
pip install geocoder
# Out:
# Requirement already satisfied: geocoder in c:\users\srina\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: click in c:\users\srina\anaconda3\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: future in c:\users\srina\anaconda3\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: requests in c:\users\srina\anaconda3\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: six in c:\users\srina\anaconda3\lib\site-packages (from geocoder) (1.13.0)
# Requirement already satisfied: ratelim in c:\users\srina\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\srina\anaconda3\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\srina\anaconda3\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\srina\anaconda3\lib\site-packages (from requests->geocoder) (1.25.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\srina\anaconda3\lib\site-packages (from requests->geocoder) (2019.11.28)
# Requirement already satisfied: decorator in c:\users\srina\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import requests
import geocoder
import io

# %%
wiki = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wiki_page = requests.get(wiki)

wiki_raw = pd.read_html(wiki_page.content, header = 0)[0]
df = wiki_raw[wiki_raw.Neighbourhood != 'Not assigned']
df.reset_index(inplace = True)
df.head(15)
# Out:
#     index Postal Code           Borough  \
# 0       2         M3A        North York
# 1       3         M4A        North York
# 2       4         M5A  Downtown Toronto
# 3       5         M6A        North York
# 4       6         M7A  Downtown Toronto
# 5       8         M9A         Etobicoke
# 6       9         M1B       Scarborough
# 7      11         M3B        North York
# 8      12         M4B         East York
# 9      13         M5B  Downtown Toronto
# 10     14         M6B        North York
# 11     17         M9B         Etobicoke
# 12     18         M1C       Scarborough
# 13     20         M3C        North York
# 14     21         M4C         East York
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Regent Park, Harbourfront
# 3                    Lawrence Manor, Lawrence Heights
# 4         Queen's Park, Ontario Provincial Government
# 5             Islington Avenue, Humber Valley Village
# 6                                      Malvern, Rouge
# 7                                           Don Mills
# 8                     Parkview Hill, Woodbine Gardens
# 9                            Garden District, Ryerson
# 10                                          Glencairn
# 11  West Deane Park, Princess Gardens, Martin Grov...
# 12             Rouge Hill, Port Union, Highland Creek
# 13                                          Don Mills
# 14                                   Woodbine Heights

# %% [markdown]
# geocoder wasn't working that's why using csv file given in the course

# %%
url = 'http://cocl.us/Geospatial_data'

# %%
datastr = requests.get('http://cocl.us/Geospatial_data',allow_redirects=True).text
data_file = io.StringIO(datastr)
df_geo = pd.read_csv(data_file)
df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#checking datatypes
df_geo.dtypes
# Out:
# Postal Code     object
# Latitude       float64
# Longitude      float64
# dtype: object

# %%
df = df.join(df_geo.set_index('Postal Code'), on='Postal Code')
df
# Out:
#      index Postal Code           Borough  \
# 0        2         M3A        North York
# 1        3         M4A        North York
# 2        4         M5A  Downtown Toronto
# 3        5         M6A        North York
# 4        6         M7A  Downtown Toronto
# ..     ...         ...               ...
# 98     160         M8X         Etobicoke
# 99     165         M4Y  Downtown Toronto
# 100    168         M7Y      East Toronto
# 101    169         M8Y         Etobicoke
# 102    178         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 6 columns]

# %%
df = df.reset_index()
df.head()
# Out:
#    level_0  index Postal Code           Borough  \
# 0        0      2         M3A        North York
# 1        1      3         M4A        North York
# 2        2      4         M5A  Downtown Toronto
# 3        3      5         M6A        North York
# 4        4      6         M7A  Downtown Toronto
#
#                                  Neighbourhood   Latitude  Longitude
# 0                                    Parkwoods  43.753259 -79.329656
# 1                             Victoria Village  43.725882 -79.315572
# 2                    Regent Park, Harbourfront  43.654260 -79.360636
# 3             Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4  Queen's Park, Ontario Provincial Government  43.662301 -79.389494

# %%
df.drop(['index'], axis = 'columns', inplace = True)
df.head()
# Out:
#    level_0 Postal Code           Borough  \
# 0        0         M3A        North York
# 1        1         M4A        North York
# 2        2         M5A  Downtown Toronto
# 3        3         M6A        North York
# 4        4         M7A  Downtown Toronto
#
#                                  Neighbourhood   Latitude  Longitude
# 0                                    Parkwoods  43.753259 -79.329656
# 1                             Victoria Village  43.725882 -79.315572
# 2                    Regent Park, Harbourfront  43.654260 -79.360636
# 3             Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4  Queen's Park, Ontario Provincial Government  43.662301 -79.389494

# %%
df = df.set_index('level_0')
df.head()
# Out:
#         Postal Code           Borough  \
# level_0
# 0               M3A        North York
# 1               M4A        North York
# 2               M5A  Downtown Toronto
# 3               M6A        North York
# 4               M7A  Downtown Toronto
#
#                                        Neighbourhood   Latitude  Longitude
# level_0
# 0                                          Parkwoods  43.753259 -79.329656
# 1                                   Victoria Village  43.725882 -79.315572
# 2                          Regent Park, Harbourfront  43.654260 -79.360636
# 3                   Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4        Queen's Park, Ontario Provincial Government  43.662301 -79.389494

# %%
df.shape
# Out:
# (103, 5)
